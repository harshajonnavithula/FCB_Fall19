# %%
import pandas
cerealproduction = pandas.read_csv('CerealProduction.csv')
cerealproductioncountry=cerealproduction.iloc[:,0:1]
cerealproductiondata = cerealproduction.iloc[:, 54:62]
cerealproductiondata = cerealproductiondata.dropna()
cerealproductiondata = cerealproductiondata.join(cerealproductioncountry)
cerealproductiondata.to_csv('CerealProductionCLEANED.csv')

# %%
cerealproductiondata['percent'] = (cerealproductiondata['2017']-cerealproductiondata['2010'])/cerealproductiondata['2010']
cerealproductiondata['slope'] = (cerealproductiondata['2017']-cerealproductiondata['2010'])/7

# %%
cerealproductiondata.sort_values('slope', ascending=False)
# Out:
#              2010          2011          2012          2013          2014  \
# 257  2.463261e+09  2.583215e+09  2.563241e+09  2.769528e+09  2.818077e+09
# 101  1.722990e+09  1.843004e+09  1.847864e+09  1.955325e+09  1.989149e+09
# 138  1.690785e+09  1.810247e+09  1.815452e+09  1.921544e+09  1.953043e+09
# 154  1.595299e+09  1.717494e+09  1.710858e+09  1.817592e+09  1.844436e+09
# 100  1.440219e+09  1.566620e+09  1.557898e+09  1.658632e+09  1.676831e+09
# 247  9.131755e+08  9.939137e+08  9.840956e+08  1.057323e+09  1.071957e+09
# 140  8.286698e+08  9.160227e+08  8.996070e+08  9.676650e+08  9.842979e+08
# 61   7.970532e+08  8.293582e+08  8.607683e+08  8.675919e+08  8.727788e+08
# 59   7.436179e+08  7.693074e+08  7.970808e+08  8.115659e+08  8.138906e+08
# 228  7.391030e+08  7.646129e+08  7.918856e+08  8.063665e+08  8.086675e+08
# 60   7.479992e+08  7.737265e+08  7.905124e+08  8.099314e+08  8.152152e+08
# 137  6.821235e+08  7.235798e+08  7.267626e+08  7.602689e+08  7.724784e+08
# ...

# %%
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'World']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'IDA & IBRD total']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Middle income']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Low & middle income']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'IBRD only']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Late-demographic dividend']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Upper middle income']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'East Asia & Pacific']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'East Asia & Pacific (excluding high income)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'East Asia & Pacific (IDA & IBRD countries)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'High income']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Post-demographic dividend']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'OECD members']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Europe & Central Asia']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'North America']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Early-demographic dividend']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'European Union']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Lower middle income']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Euro area']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Middle East & North Africa']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Latin America & the Caribbean (IDA & IBRD countries)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Latin America & Caribbean']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Arab World']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Latin America & Caribbean (excluding high income)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Europe & Central Asia (IDA & IBRD countries)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Europe & Central Asia (excluding high income)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Small states']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'South Asia (IDA & IBRD)']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'South Asia']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Other small states']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Pre-demographic dividend']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Central Europe and the Baltics']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'IDA total']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'IDA blend']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'Least developed countries: UN classification']
cerealproductiondata=cerealproductiondata[cerealproductiondata['Country Name'] != 'IDA only']

# %%
cerealproductiondataSlope=cerealproductiondata.sort_values('slope', ascending=False)
cerealproductiondataPercent=cerealproductiondata.sort_values('percent', ascending=False)

# %%
top5Slope = cerealproductiondataSlope.iloc[0:5, 0:9]
top5tSlope = top5Slope.T
top5Percent = cerealproductiondataPercent.iloc[0:5, 0:9]
top5tPercent = top5Percent.T

# %%
top5tdataSlope = top5tSlope[0:8]
top5tdataSlope
top5tdataPercent = top5tPercent[0:8]
top5tdataPercent
# Out:
#         180   170          2            200   29
# 2010  19976  3335  1.18194e+06  5.96191e+07  1072
# 2011  21786  2597  1.41283e+06  9.17809e+07  1480
# 2012  20407  4198       509545  6.87535e+07  1756
# 2013  19188  4386   1.6746e+06   9.0365e+07  1237
# 2014  16752  4815  1.82344e+06  1.03136e+08  1382
# 2015  78976  7074  2.02011e+06  1.02445e+08  1983
# 2016  63192  8847  2.42433e+06  1.17744e+08  1579
# 2017  63411  9621  2.89127e+06  1.31144e+08  2349

# %%
top5tdataSlope.columns  = top5Slope['Country Name']
top5tdataPercent.columns  = top5Percent['Country Name']

# %%
ax = top5tdataSlope.plot()
ax.set_xlabel("Years")
ax.set_ylabel("Cereal Production in tons Rate of Change")
ax.set_xticklabels(top5tdataSlope.index, rotation=0)
# Out:
# [Text(0, 0, '2010'),
#  Text(0, 0, '2011'),
#  Text(0, 0, '2012'),
#  Text(0, 0, '2013'),
#  Text(0, 0, '2014'),
#  Text(0, 0, '2015'),
#  Text(0, 0, '2016'),
#  Text(0, 0, '2017')]

# %%
ax = top5tdataPercent.plot()
ax.set_xlabel("Years")
ax.set_ylabel("Cereal Production in tons % increase")
ax.set_xticklabels(top5tdataPercent.index, rotation=0)
# Out:
# [Text(0, 0, '2010'),
#  Text(0, 0, '2011'),
#  Text(0, 0, '2012'),
#  Text(0, 0, '2013'),
#  Text(0, 0, '2014'),
#  Text(0, 0, '2015'),
#  Text(0, 0, '2016'),
#  Text(0, 0, '2017')]
